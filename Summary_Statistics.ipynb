# %% [markdown]
# # Summary Statistics
#
# Preksha Sarda

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('loan_approval_dataset.csv')
df.head()
# Out:
#    loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0        1                  2       Graduate             No        9600000
# 1        2                  0   Not Graduate            Yes        4100000
# 2        3                  3       Graduate             No        9100000
# 3        4                  3       Graduate             No        8200000
# 4        5                  5   Not Graduate            Yes        9800000
#
#     loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0      29900000          12           778                    2400000
# 1      12200000           8           417                    2700000
# 2      29700000          20           506                    7100000
# 3      30700000           8           467                   18200000
# 4      24200000          20           382                   12400000
#
#     commercial_assets_value   luxury_assets_value   bank_asset_value  \
# ...

# %%
df.columns
# Out:
# Index(['loan_id', ' no_of_dependents', ' education', ' self_employed',
#        ' income_annum', ' loan_amount', ' loan_term', ' cibil_score',
#        ' residential_assets_value', ' commercial_assets_value',
#        ' luxury_assets_value', ' bank_asset_value', ' loan_status'],
#       dtype='object')

# %%
plt.hist(df[' loan_status'])
plt.title("Number of Loans Denied and Approved")
# Out:
# Text(0.5, 1.0, 'Number of Loans Denied and Approved')

# %% [markdown]
# We should stratify the targets

# %%
df[' education'].value_counts()
# Out:
#  education
# Graduate        2144
# Not Graduate    2125
# Name: count, dtype: int64

# %%
plt.hist(df[' income_annum'])
plt.title("Annual Income Across the Dataset")
plt.ylabel("Frequency")
plt.xlabel("Income")
# Out:
# Text(0.5, 0, 'Income')

# %%
df[' loan_term'].value_counts()
# Out:
#  loan_term
# 6     490
# 12    456
# 4     447
# 10    436
# 18    422
# 16    412
# 20    411
# 14    405
# 2     404
# 8     386
# Name: count, dtype: int64

# %% [markdown]
# Dataset seems fairly balanced

# %%
plt.scatter(df[' income_annum'], df[' luxury_assets_value'])
plt.xlabel("Annual Income")
plt.ylabel("Luxury Asset Value")
plt.title("Annual Income Compared Against Luxury Assets Value")
# Out:
# Text(0.5, 1.0, 'Annual Income Compared Against Luxury Assets Value')

# %% [markdown]
# We get more disparity in luxury asset values as annual income increases.

# %%
plt.scatter(df[' income_annum'], df[' loan_status'])
plt.xlabel("Annual Income")
plt.ylabel("Loan Status")
plt.title("Does Annual Income directly relate to Loan Status?")
# Out:
# Text(0.5, 1.0, 'Does Annual Income directly relate to Loan Status?')

# %% [markdown]
# This plot shows that income is definietly not the only factor in determining loan status
